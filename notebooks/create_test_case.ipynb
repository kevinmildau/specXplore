# %%
# %load_ext autoreload
# %autoreload 2
from specxploreImporting import importing
from specxploreImporting.importing import attach_metadata, construct_metadata
import matchms
from matchms.importing import load_from_mgf
from matchms.exporting import save_as_mgf
from ms2query.run_ms2query import download_zenodo_files, run_complete_folder
from ms2query.ms2library import create_library_object_from_one_dir
import os
import pandas as pd
import numpy as np
from typing import List
models_and_library_folder_pos = os.path.join("data_and_output", "models", "pos")
raw_experimental_mgf_filename = os.path.join("data_and_output", "test_data", "MonoisotopicMS2Feature_pos_mostIntense.mgf")
raw_standards_mgf_filename = os.path.join("data_and_output", "test_data", "phophe_pos.mgf")
processed_experimental_spectra_filename = os.path.join("data_and_output", "test_data", "spectra_experimental.mgf")
processed_standard_spectra_filename = os.path.join("data_and_output", "test_data", "spectra_standards.mgf")
csv_experimental_filename = os.path.join("data_and_output", "test_data", "test_data_ms2query_out_experimental.csv")
csv_standards_filename = os.path.join("data_and_output", "test_data", "test_data_ms2query_out_standard.csv")
scores_s2v_filename = os.path.join("data_and_output", "test_data", "s2v.npy")
scores_ms2ds_filename = os.path.join("data_and_output", "test_data", "ms2ds.npy")
scores_cos_filename = os.path.join("data_and_output", "test_data", "cos.npy")

# %%
spectra_experimental = list(load_from_mgf(raw_experimental_mgf_filename))
spectra_standards = list(load_from_mgf(raw_standards_mgf_filename))
#(inspect.getmembers(spectra_experimental[0]))
#pectra_experimental[0].get("pepmass")

# %%
print(spectra_experimental[0].metadata["feature_id"])
print(spectra_standards[0].metadata["feature_id"])
# Out:
# 1961
# FT01

# %%
if False: # inspect new spectrum objects
    spec = spectra_experimental[0]
    spec = matchms.filtering.default_filters(spec)
    spec = matchms.filtering.normalize_intensities(spec)
    spec = matchms.filtering.select_by_relative_intensity(spec, 0.01, 1)
    spec = matchms.filtering.select_by_relative_intensity(spec, 0.01, 1)
    spec = matchms.filtering.repair_inchi_inchikey_smiles(spec)
    spec = matchms.filtering.harmonize_undefined_inchi(spec)
    spec = matchms.filtering.harmonize_undefined_inchikey(spec)
    spec = matchms.filtering.harmonize_undefined_smiles(spec)
    print(spec.get("precursor_mz"))
    print(spec.get("rtinseconds"))
    print(spec.peaks.mz)
    print(spec.peaks.intensities)
    print(len(spec.peaks.mz) == len(spec.peaks.intensities))
    print(spec.peaks.to_numpy)
    print(spec.metadata)

# %%
if False: # avoid adding to the spectra on each jupyter notebook rerun
    spectra_experimental = list(load_from_mgf(raw_experimental_mgf_filename))
    spectra_experimental = importing.clean_spectra(spectra_experimental)[0:20]
    save_as_mgf(spectra_experimental, processed_experimental_spectra_filename)

    spectra_standards = list(load_from_mgf(raw_standards_mgf_filename))
    spectra_standards = importing.clean_spectra(spectra_standards)[0:10]
    save_as_mgf(spectra_standards, processed_standard_spectra_filename)

# %%
spectra_experimental = list(load_from_mgf(processed_experimental_spectra_filename))
spectra_standards = list(load_from_mgf(processed_standard_spectra_filename))

# %%
if False:
    importing.run_single_file(ms2library, processed_standard_spectra_filename, str(csv_standards_filename))
    importing.run_single_file(ms2library, processed_experimental_spectra_filename, str(csv_experimental_filename))

# %%
classes_experimental = pd.read_csv(csv_experimental_filename)
classes_experimental = importing.expand_ms2query_results_table(classes_experimental, len(spectra_experimental))
classes_standards = pd.read_csv(csv_standards_filename)
classes_standards = importing.expand_ms2query_results_table(classes_standards, len(spectra_standards))

# %%
classes_experimental["is_standard"] = False
classes_experimental["exp_metadata"] = None
classes_standards["is_standard"] = True
classes_standards["standard_metadata"] = None
all_class_table = pd.merge(classes_experimental, classes_standards, how = 'outer').reset_index()
all_class_table["specxplore_id"] = all_class_table.index
all_class_table
# Out:
#     index  query_spectrum_nr  ms2query_model_prediction  \
# 0       0                  1                     0.3775
# 1       1                  2                     0.7120
# 2       2                  3                     0.7416
# 3       3                  4                     0.7399
# 4       4                  5                     0.4090
# 5       5                  6                     0.8399
# 6       6                  7                     0.7312
# 7       7                  8                     0.6237
# 8       8                  9                     0.7119
# 9       9                 10                     0.6202
# 10     10                 11                     0.7843
# 11     11                 12                     0.8187
# 12     12                 13                     0.2939
# 13     13                 14                     0.8558
# 14     14                 15                     0.8710
# 15     15                 16                     0.8558
# 16     16                 17                     0.8710
# 17     17                 18                     0.7187
# 18     18                 19                     0.7621
# 19     19                 20                     0.8558
# 20     20                  1                     0.7530
# 21     21                  2                     0.8329
# 22     22                  3                     0.8768
# 23     23                  4                     0.8699
# 24     24                  5                     0.8491
# 25     25                  6                     0.8798
# 26     26                  7                     0.8714
# 27     27                  8                     0.8744
# 28     28                  9                     0.4090
# 29     29                 10                     0.8556
#
#     precursor_mz_difference  precursor_mz_query_spectrum  precursor_mz_analog  \
# 0                  123.0081                     105.0339              228.042
# 1                    0.0007                     113.0237              113.023
# 2                    0.0001                     120.0809              120.081
# 3                    0.0006                     122.0966              122.096
# 4                  310.2715                     125.0235              435.295
# 5                    0.0004                     127.0504              127.050
# 6                    0.0002                     136.0618              136.062
# 7                    0.0001                     143.0339              143.034
# 8                    0.0006                     144.0656              144.065
# 9                    0.0006                     144.0656              144.065
# 10                   0.0002                     144.0808              144.081
# 11                   0.0002                     144.0808              144.081
# 12                 213.0926                     145.0864              358.179
# 13                   0.0000                     146.0600              146.060
# 14                   0.0000                     146.0600              146.060
# 15                   0.0001                     146.0601              146.060
# 16                   0.0001                     146.0601              146.060
# 17                   0.0006                     146.1176              146.117
# 18                   0.0000                     147.0440              147.044
# 19                   0.0000                     147.0440              147.044
# 20                   0.0002                     149.0598              149.060
# 21                   0.0006                     180.0654              180.066
# 22                   0.0001                     181.0491              181.049
# 23                   0.0002                     195.0652              195.065
# 24                   0.0001                     195.0649              195.065
# 25                   0.0005                     243.1015              243.101
# 26                   0.0003                     255.0647              255.065
# 27                   0.0003                     271.0597              271.060
# 28                 316.1144                     275.0846              591.199
# 29                   0.0006                     285.0754              285.076
#
#           inchikey  spectrum_ids  \
# 0   ZCGLNFAUVVHTQO        276075
# 1   IHCCAYCGZOLTEU        303482
# 2   LPAGFVYQRIESJQ        313913
# 3   UFFBMTHBGFGIHF        274723
# 4   SCABKEBYDRTODC        265703
# 5   RWQNBRDOKXIBIV        303494
# 6   GFFGJBXGBJISGV         57697
# 7   PCSKKIUURRTAEM        306586
# 8   OYIFNHCXNCRBQI         28452
# 9   XLBVNMSMFQMKEY         28339
# 10  APJYDQYYACXCRM         26468
# 11  APJYDQYYACXCRM         26468
# 12  QANQWUQOEJZMLL          9765
# 13  OVYWMEWYEJLIER        247282
# 14  VDBNYAPERZTOOF        247081
# 15  MCJGNVYPOGVAJF        265233
# 16  VDBNYAPERZTOOF        247081
# 17  QVDXUKJJGUSGLS          3730
# 18  PMOWTIHVNWZYFI         67573
# 19  NGSWKAQJJWESNS         60934
# 20  WBYWAXJHAXSJNI        304135
# 21  QIAFMBKCNZACKA        304050
# 22  QAIPRVGONGVQAS        255081
# 23  KSEBMYQBYZTDHS         62728
# 24  KSEBMYQBYZTDHS         62728
# 25  ADFCQWZHKCXPAJ         25871
# 26  GPGOCTLAUAHUQO         68703
# 27  TZBJGXHYKVUXJN         74997
# 28  IAFBOKYTDSDNHV         20022
# 29  DANYIYRPLHHOCZ        236357
#
#                                  analog_compound_name  retention_time  ...  \
# 0            3-[(4-chlorobenzoyl)amino]propanoic acid             NaN  ...
# 1                                       3-FUROIC ACID             NaN  ...
# 2                                             Indolin             NaN  ...
# 3                                 2,6-Dimethylaniline             NaN  ...
# 4           bis[2-(2-butoxyethoxy)ethyl] hexanedioate             NaN  ...
# 5                                             THYMINE             NaN  ...
# 6                                             adenine             NaN  ...
# 7              5-HYDROXYMETHYL-2-FURANCARBOXYLIC ACID             NaN  ...
# 8                                        AMINOADIPATE             NaN  ...
# 9                                   N-METHYLGLUTAMATE             NaN  ...
# 10                                         Tryptamine             NaN  ...
# 11                                         Tryptamine             NaN  ...
# 12                                      CinacalcetHCl             NaN  ...
# 13                                      Quinolin-6-ol             NaN  ...
# 14                               2H-isoquinolin-1-one             NaN  ...
# 15                                      quinolin-8-ol             NaN  ...
# 16                               2H-isoquinolin-1-one             NaN  ...
# 17                               Leucine methyl ester             NaN  ...
# 18                             2-Hydroxycinnamic acid             NaN  ...
# 19                                    p-coumaric acid             NaN  ...
# 20                                      CINNAMIC ACID             NaN  ...
# 21                                      HIPPURIC ACID             NaN  ...
# 22                                       Caffeic acid             NaN  ...
# 23                                       ferulic acid             NaN  ...
# 24                                       ferulic acid             NaN  ...
# 25                                              Equol             NaN  ...
# 26                              3,4'-Dihydroxyflavone             NaN  ...
# 27                                          Genistein             NaN  ...
# 28  5,7-dimethoxy-2-phenyl-2,3-dihydrochromen-4-on...             NaN  ...
# 29                                  BML00818 Acacetin             NaN  ...
#
#                                cf_subclass                  cf_direct_parent  \
# 0     Amino acids, peptides, and analogues  Beta amino acids and derivatives
# 1              Furoic acid and derivatives                      Furoic acids
# 2                                Indolines                         Indolines
# 3                                  Xylenes                         m-Xylenes
# 4                        Fatty acid esters                 Fatty acid esters
# 5   Pyrimidines and pyrimidine derivatives                Hydroxypyrimidines
# 6           Purines and purine derivatives                    6-aminopurines
# 7                                      NaN                               NaN
# 8     Amino acids, peptides, and analogues                 Alpha amino acids
# 9     Amino acids, peptides, and analogues     Glutamic acid and derivatives
# 10             Tryptamines and derivatives       Tryptamines and derivatives
# 11             Tryptamines and derivatives       Tryptamines and derivatives
# 12                                     NaN                      Naphthalenes
# 13                       Hydroxyquinolines                 Hydroxyquinolines
# 14           Isoquinolones and derivatives     Isoquinolones and derivatives
# 15                     8-hydroxyquinolines               8-hydroxyquinolines
# 16           Isoquinolones and derivatives     Isoquinolones and derivatives
# 17    Amino acids, peptides, and analogues           Leucine and derivatives
# 18   Hydroxycinnamic acids and derivatives             Hydroxycinnamic acids
# 19   Hydroxycinnamic acids and derivatives             Hydroxycinnamic acids
# 20                          Cinnamic acids                    Cinnamic acids
# 21           Benzoic acids and derivatives                    Hippuric acids
# 22   Hydroxycinnamic acids and derivatives             Hydroxycinnamic acids
# 23   Hydroxycinnamic acids and derivatives             Hydroxycinnamic acids
# 24   Hydroxycinnamic acids and derivatives             Hydroxycinnamic acids
# 25                              Isoflavans                      Isoflavanols
# 26                                     NaN                               NaN
# 27                          Isoflav-2-enes                       Isoflavones
# 28                 O-methylated flavonoids         7-O-methylated flavonoids
# 29                 O-methylated flavonoids        4'-O-methylated flavonoids
#
#                        npc_class_results  \
# 0                                    NaN
# 1                                    NaN
# 2                    Carboline alkaloids
# 3                                    NaN
# 4                       Triacylglycerols
# 5   Purine alkaloids; Pyridine alkaloids
# 6                       Purine alkaloids
# 7                                    NaN
# 8                             Aminoacids
# 9                             Aminoacids
# 10               Simple indole alkaloids
# 11               Simple indole alkaloids
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                        Wax monoesters
# 18        Cinnamic acids and derivatives
# 19        Cinnamic acids and derivatives
# 20        Cinnamic acids and derivatives
# 21                            Dipeptides
# 22        Cinnamic acids and derivatives
# 23        Cinnamic acids and derivatives
# 24        Cinnamic acids and derivatives
# 25                         Isoflavanones
# 26                                   NaN
# 27                           Isoflavones
# 28                            Flavanones
# 29                              Flavones
#
#                                npc_superclass_results  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                Tryptophan alkaloids
# 3                                                 NaN
# 4                                       Glycerolipids
# 5   Pseudoalkaloids (transamidation); Nicotinic ac...
# 6                    Pseudoalkaloids (transamidation)
# 7                                                 NaN
# 8                                      Small peptides
# 9                                      Small peptides
# 10                               Tryptophan alkaloids
# 11                               Tryptophan alkaloids
# 12                                                NaN
# 13                               Tryptophan alkaloids
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                       Fatty esters
# 18                           Phenylpropanoids (C6-C3)
# 19                           Phenylpropanoids (C6-C3)
# 20                           Phenylpropanoids (C6-C3)
# 21                                     Small peptides
# 22                           Phenylpropanoids (C6-C3)
# 23                           Phenylpropanoids (C6-C3)
# 24                           Phenylpropanoids (C6-C3)
# 25                                      Isoflavonoids
# 26                                                NaN
# 27                                      Isoflavonoids
# 28                                         Flavonoids
# 29                                         Flavonoids
#
#                 npc_pathway_results source_spectrum_mgf_iloc is_standard  \
# 0                               NaN                        0       False
# 1                               NaN                        1       False
# 2                         Alkaloids                        2       False
# 3                               NaN                        3       False
# 4                       Fatty acids                        4       False
# 5                         Alkaloids                        5       False
# 6                         Alkaloids                        6       False
# 7                               NaN                        7       False
# 8          Amino acids and Peptides                        8       False
# 9          Amino acids and Peptides                        9       False
# 10                        Alkaloids                       10       False
# 11                        Alkaloids                       11       False
# 12                              NaN                       12       False
# 13                        Alkaloids                       13       False
# 14                        Alkaloids                       14       False
# 15                        Alkaloids                       15       False
# 16                        Alkaloids                       16       False
# 17                      Fatty acids                       17       False
# 18  Shikimates and Phenylpropanoids                       18       False
# 19  Shikimates and Phenylpropanoids                       19       False
# 20  Shikimates and Phenylpropanoids                        0        True
# 21         Amino acids and Peptides                        1        True
# 22  Shikimates and Phenylpropanoids                        2        True
# 23  Shikimates and Phenylpropanoids                        3        True
# 24  Shikimates and Phenylpropanoids                        4        True
# 25  Shikimates and Phenylpropanoids                        5        True
# 26                              NaN                        6        True
# 27  Shikimates and Phenylpropanoids                        7        True
# 28  Shikimates and Phenylpropanoids                        8        True
# 29  Shikimates and Phenylpropanoids                        9        True
#
#    exp_metadata standard_metadata specxplore_id
# 0          None               NaN             0
# 1          None               NaN             1
# 2          None               NaN             2
# 3          None               NaN             3
# 4          None               NaN             4
# 5          None               NaN             5
# 6          None               NaN             6
# 7          None               NaN             7
# 8          None               NaN             8
# 9          None               NaN             9
# 10         None               NaN            10
# 11         None               NaN            11
# 12         None               NaN            12
# 13         None               NaN            13
# 14         None               NaN            14
# 15         None               NaN            15
# 16         None               NaN            16
# 17         None               NaN            17
# 18         None               NaN            18
# 19         None               NaN            19
# 20          NaN              None            20
# 21          NaN              None            21
# 22          NaN              None            22
# 23          NaN              None            23
# 24          NaN              None            24
# 25          NaN              None            25
# 26          NaN              None            26
# 27          NaN              None            27
# 28          NaN              None            28
# 29          NaN              None            29
#
# [30 rows x 25 columns]

# %%
all_spectra = spectra_experimental + spectra_standards # list addition

# %%
scores_s2v = importing.compute_similarities_s2v(all_spectra, models_and_library_folder_pos)
scores_cos = importing.compute_similarities_cosine(all_spectra, cosine_type="ModifiedCosine")
scores_ms2ds = importing.compute_similarities_ms2ds(all_spectra, models_and_library_folder_pos)
# Out:
# 2023-04-20 09:24:48,239:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,239:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,792:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,793:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,794:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,794:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,794:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,795:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,795:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,795:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,796:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,797:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,797:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,798:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,798:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,798:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,799:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,799:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,799:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,800:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,800:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,801:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,801:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,802:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,803:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,803:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,804:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,804:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,804:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,805:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,805:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,805:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,806:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,806:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,807:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,807:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,808:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,808:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,808:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,809:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,810:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,810:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,810:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,811:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,811:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,811:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,812:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,812:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,812:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,813:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,813:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,814:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,814:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,815:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,815:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,815:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,816:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,816:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,816:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,817:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,817:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,817:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,818:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,819:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,820:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,820:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,821:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,821:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,822:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,822:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,823:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,823:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,823:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,824:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,824:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,824:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,825:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,825:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,826:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,826:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,828:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,831:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,832:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,834:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,835:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,836:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,837:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,838:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,840:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,841:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,842:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,845:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,848:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,849:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,850:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,851:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,853:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,853:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,854:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,854:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,854:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,855:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,855:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,855:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,856:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,856:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,857:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,857:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,857:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,858:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,858:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,859:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,861:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,862:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,863:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,865:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,865:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,866:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,866:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,866:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,867:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,867:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,868:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,868:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,869:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,869:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,870:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,870:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,871:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,871:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,872:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,872:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,872:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,873:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,874:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,874:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,874:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,875:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,875:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,875:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,876:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,876:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,877:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,877:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,878:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,878:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,878:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,879:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,879:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,880:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,880:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,880:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,881:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,881:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,881:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,882:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,882:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,883:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,883:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,883:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,884:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,884:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,885:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,886:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,886:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,887:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,887:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,887:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,888:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,888:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,889:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,889:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,890:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,890:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,890:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,891:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,891:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,892:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,892:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,892:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,893:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,893:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,894:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,894:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,894:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,895:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,895:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,896:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,896:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,896:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,897:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,897:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,897:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,898:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,898:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,898:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,899:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,899:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,900:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,900:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,901:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,901:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,901:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,902:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,902:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,903:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,903:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,903:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,904:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,904:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,905:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,905:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,905:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,905:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,906:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,906:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,907:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,907:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,907:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,908:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,908:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,909:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,909:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,909:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,910:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,910:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,911:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,911:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,912:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,912:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,912:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,913:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,913:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,913:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,914:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,914:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,915:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,915:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,915:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,916:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,916:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,916:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,917:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,917:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,917:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,918:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,919:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,919:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,920:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,921:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,923:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,924:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,925:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,926:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,928:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,929:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,931:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,932:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,934:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,935:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,937:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,937:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,938:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,939:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,941:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,942:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,942:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,943:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,944:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,945:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,946:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,946:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,947:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,947:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,947:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,948:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,948:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,948:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,949:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,949:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,949:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,949:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,950:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,951:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,953:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,954:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,955:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,956:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,956:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,957:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,958:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,958:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,959:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,959:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,960:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,960:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,961:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,961:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,961:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,962:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,962:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,962:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,962:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,963:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,964:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,964:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,964:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,965:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,965:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,966:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,966:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,967:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,968:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,968:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,969:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,969:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,969:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,970:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,970:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,970:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,971:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,971:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,972:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,972:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,973:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,973:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,974:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,974:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,974:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,975:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,975:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,976:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,976:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,976:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,977:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,977:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,978:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,978:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,978:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,979:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,979:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,979:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,980:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,980:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,981:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,981:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,982:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,982:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,982:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:48,983:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# ...
# 2023-04-20 09:24:49,387:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,388:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,388:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,389:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,390:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,390:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,391:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,391:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,392:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,392:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,392:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,393:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,393:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,393:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,394:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,394:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,395:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,395:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,395:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,396:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,396:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,396:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,397:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,397:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,398:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,398:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,400:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,402:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,404:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,405:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,406:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,407:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,408:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,409:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,410:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,410:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,411:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,411:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,412:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,413:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,414:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,414:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,415:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,416:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,416:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,417:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,417:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,418:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,418:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,419:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,420:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,420:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,421:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,422:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,422:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,423:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,423:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,424:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,424:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,425:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,425:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,426:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,426:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,427:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,428:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,428:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,429:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,430:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,430:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,431:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,431:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,432:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,432:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,433:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,434:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,434:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,435:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,435:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,435:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,436:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,436:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,437:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,438:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,438:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,438:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,439:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,439:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,439:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,441:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,442:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,442:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,443:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,444:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,444:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,445:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,446:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,448:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,448:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,448:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,449:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,449:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,450:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,451:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,454:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,458:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,459:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,460:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,460:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,461:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,462:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,464:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,465:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,469:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# 2023-04-20 09:24:49,472:WARNING:matchms:ModifiedCosine:Precursor_mz must be of type int or float. Apply 'add_precursor_mz' filter first.
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# Spectrum binning: 100%|██████████| 30/30 [00:00<00:00, 18436.50it/s]
# Create BinnedSpectrum instances: 100%|██████████| 30/30 [00:00<00:00, 232586.17it/s]
# Calculating vectors of reference spectrums: 100%|██████████| 30/30 [00:00<00:00, 30.12it/s]

# %%
k_values = [3, 5, 10]
random_seeds = [int(np.random.randint(0,1000)) for _ in k_values]
similarities = scores_ms2ds
distances = importing.convert_similarity_to_distance(similarities)
kmedoid_list = importing.run_kmedoid_grid(distances, k_values, random_seeds)
importing.render_kmedoid_fitting_results_in_browser(kmedoid_list)

# %%
perplexity_values = [x for x in [20]]
random_seeds = [int(np.random.randint(0,1000)) for _ in perplexity_values]
tsne_list_pos = importing.run_tsne_grid(distances, perplexity_values, random_seeds)
importing.render_tsne_fitting_results_in_browser(tsne_list_pos)

# %%
# %load_ext autoreload
# %autoreload 2
import specxplore.specxplore_data
from specxplore.specxplore_data import specxplore_data, Spectrum, load_specxplore_object_from_pickle
is_standard = np.array(all_class_table["is_standard"])
spec_classes = all_class_table[['cf_kingdom', 'cf_superclass', 'cf_class', 'cf_subclass',
       'cf_direct_parent', 'npc_class_results', 'npc_superclass_results',
       'npc_pathway_results']]
mz = [spec.get("precursor_mz") for spec in all_spectra]
# KmedoidGridEntry(k, cluster_assignments, score, random_states[idx])
kclass_table = pd.DataFrame()
for elem in kmedoid_list:
    kclass_table[elem.k] = elem.cluster_assignments
classes = pd.concat([spec_classes, kclass_table], axis=1)
tsnedf = pd.DataFrame({"x" : tsne_list_pos[0].x_coordinates, "y" : tsne_list_pos[0].y_coordinates})
specxplore_id = np.array(all_class_table["specxplore_id"])

tsnedf["is_standard"] = is_standard
tsnedf["id"] = specxplore_id

def convert_matchms_spectra_to_specxplore_spectrum(spectra = List[matchms.Spectrum]) -> List[Spectrum]:
  spectra_converted = [
      Spectrum(spec.peaks.mz, float(spec.get("precursor_mz")), idx, spec.peaks.intensities) 
      for idx, spec in enumerate(all_spectra)]
  return spectra_converted

spectra_converted = convert_matchms_spectra_to_specxplore_spectrum(all_spectra)
test_data_specxplore = specxplore_data(
  scores_ms2ds,scores_s2v, scores_cos, tsnedf,  classes,
  is_standard, spectra_converted, mz, specxplore_id)

import pickle
with open('data_and_output/test_data/test_case_specxplore5.pickle', 'wb') as file:
  pickle.dump(test_data_specxplore, file)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
metadata = construct_metadata(all_spectra)

# %%
complete_spectrum_data = [spectrum.metadata for spectrum in all_spectra]
complete_spectrum_data = pd.DataFrame.from_records(complete_spectrum_data)
selected_spectrum_data = complete_spectrum_data.loc[:, ["feature_id", "rtinseconds", "precursor_mz"]]

# %%
updated_metadata = attach_metadata(metadata, selected_spectrum_data)
known_compounds = pd.DataFrame({
    "feature_id" : ['1961', 'FT13' ], 
    "chemical_name" : ["metabo1", "metabo2"]})
updated_metadata = attach_metadata(updated_metadata, known_compounds)
print(updated_metadata["chemical_name"].iloc[2], type(updated_metadata["chemical_name"].iloc[2]))
# Out:
# nan <class 'float'>

# %%
test_data_specxplore.save_selection_to_file("tmp.pickle", [5,6,10,20])
new_dat = load_specxplore_object_from_pickle("tmp.pickle")

for i in [5,6,10,20]:
    print(test_data_specxplore.spectra[i].identifier)
    print(max(test_data_specxplore.spectra[i].mass_to_charge_ratios))

for spectrum in new_dat.spectra:
    print(spectrum.identifier)
    print(max(spectrum.mass_to_charge_ratios))
# Out:
# 0
# 127.05942
# 1
# 137.04594
# 2
# 155.06053
# 3
# 149.082326253255
# 0
# 127.05942
# 1
# 137.04594
# 2
# 155.06053
# 3
# 149.082326253255
